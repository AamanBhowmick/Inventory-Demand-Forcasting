# %%
#pip install pandas numpy seaborn matplotlib klib dtale scikit-learn joblib pandas-profiling
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ---------------------------------------- 14.0/14.0 MB 8.2 MB/s eta 0:00:00
# ...
#      ------------------------------------- 324.4/324.4 kB 10.1 MB/s eta 0:00:00
# ...
#      --------------------------------------- 10.2/10.2 MB 10.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 96.5/96.5 kB 5.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 65.9/65.9 MB 5.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 9.1/9.1 MB 9.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.0/2.0 MB 10.8 MB/s eta 0:00:00
# ...
#      ------------------------------------- 250.0/250.0 kB 16.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 15.3/15.3 MB 7.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 219.7/219.7 kB 3.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 40.1/40.1 MB 7.2 MB/s eta 0:00:00
# ...

# %%
pip install pandas-profiling
# Out:
# ...
#   Using cached pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
# ...
#   Using cached ydata_profiling-4.1.2-py2.py3-none-any.whl (345 kB)
# ...
#   Using cached statsmodels-0.13.5-cp310-cp310-win_amd64.whl (9.1 MB)
# ...
#   Using cached multimethod-1.9.1-py3-none-any.whl (10 kB)
# ...
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# ...
#   Using cached scipy-1.9.3-cp310-cp310-win_amd64.whl (40.1 MB)
# ...
#   Using cached phik-0.12.3-cp310-cp310-win_amd64.whl (663 kB)
# ...
#   Using cached pandas-1.5.3-cp310-cp310-win_amd64.whl (10.4 MB)
# ...
#   Using cached visions-0.7.5-py3-none-any.whl (102 kB)
# ...
#   Using cached PyWavelets-1.4.1-cp310-cp310-win_amd64.whl (4.2 MB)
# ...
#   Using cached networkx-3.0-py3-none-any.whl (2.0 MB)
# ...
#   Using cached patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
pip install joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train= pd.read_csv('train.csv')
df_test= pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
#df_test

# %%
df_train.shape
# Out:
# (8523, 12)

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df_train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# ### Item_Weight is numerical column so we fill it with Mean Imputation

# %%
df_train['Item_Weight'].describe()
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df_train['Item_Weight'].fillna(df_train['Item_Weight'].mean(),inplace=True)
df_test['Item_Weight'].fillna(df_test['Item_Weight'].mean(),inplace=True)

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_train['Item_Weight'].describe()
# Out:
# count    8523.000000
# mean       12.857645
# std         4.226124
# min         4.555000
# 25%         9.310000
# 50%        12.857645
# 75%        16.000000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %% [markdown]
# ### Outlet_Size is catagorical column so we fill it with Mode Imputation

# %%
df_train['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df_train['Outlet_Size'].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
df_train['Outlet_Size'].fillna(df_train['Outlet_Size'].mode()[0],inplace=True)
df_test['Outlet_Size'].fillna(df_test['Outlet_Size'].mode()[0],inplace=True)

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %% [markdown]
# # Selecting features based on general requirements

# %%
df_train.drop(['Item_Identifier','Outlet_Identifier','Item_Fat_Content'],axis=1,inplace=True)
df_test.drop(['Item_Identifier','Outlet_Identifier','Item_Fat_Content'],axis=1,inplace=True)

# %%
df_train
# Out:
#       Item_Weight  Item_Visibility              Item_Type  Item_MRP  \
# 0           9.300         0.016047                  Dairy  249.8092
# 1           5.920         0.019278            Soft Drinks   48.2692
# 2          17.500         0.016760                   Meat  141.6180
# 3          19.200         0.000000  Fruits and Vegetables  182.0950
# 4           8.930         0.000000              Household   53.8614
# ...           ...              ...                    ...       ...
# 8518        6.865         0.056783            Snack Foods  214.5218
# 8519        8.380         0.046982           Baking Goods  108.1570
# 8520       10.600         0.035186     Health and Hygiene   85.1224
# 8521        7.210         0.145221            Snack Foods  103.1332
# 8522       14.800         0.044878            Soft Drinks   75.4670
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# ...

# %% [markdown]
# # EDA using Pandas Profiling

# %%
from pandas_profiling import ProfileReport
# Out:
# C:\Users\Sakshi\AppData\Local\Temp\ipykernel_10900\2274191625.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df_train, title="Pandas Profiling Report")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-04-02 14:02:14.726065&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # EDA using Klib Library

# %%
pip install klib
# Out:
# ...
#   Using cached klib-1.0.7-py3-none-any.whl (20 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import klib

# %%
# klib.describe - functions for visualizing datasets
klib.cat_plot(df_train) # returns a visualization of the number and frequency of categorical features
# Out:
# GridSpec(6, 4)

# %%
klib.corr_mat(df_train) # returns a color-encoded correlation matrix
# Out:
# <style type="text/css">
# #T_7cc52_row0_col0, #T_7cc52_row0_col2, #T_7cc52_row0_col4, #T_7cc52_row1_col1, #T_7cc52_row2_col0, #T_7cc52_row2_col2, #T_7cc52_row2_col3, #T_7cc52_row2_col4, #T_7cc52_row3_col2, #T_7cc52_row3_col3, #T_7cc52_row4_col0, #T_7cc52_row4_col2, #T_7cc52_row4_col4 {
#   color: None;
# }
# #T_7cc52_row0_col1, #T_7cc52_row0_col3, #T_7cc52_row1_col0, #T_7cc52_row1_col2, #T_7cc52_row1_col3, #T_7cc52_row1_col4, #T_7cc52_row2_col1, #T_7cc52_row3_col0, #T_7cc52_row3_col1, #T_7cc52_row3_col4, #T_7cc52_row4_col1, #T_7cc52_row4_col3 {
#   color: #FF3344;
# }
# </style>
# <table id="T_7cc52">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cc52_level0_col0" class="col_heading level0 col0" >Item_Weight</th>
#       <th id="T_7cc52_level0_col1" class="col_heading level0 col1" >Item_Visibility</th>
#       <th id="T_7cc52_level0_col2" class="col_heading level0 col2" >Item_MRP</th>
# ...

# %%
klib.corr_plot(df_train) # returns a color-encoded heatmap, ideal for correlations
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df_train) # returns a distribution plot for every numeric feature
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
klib.missingval_plot(df_train) # returns a figure containing information about missing values
# Out:
# No missing values found in the dataset.

# %% [markdown]
# # Data Cleaning using Klib Library

# %%
# klib.clean - functions for cleaning datasets
klib.data_cleaning(df_train) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
# Out:
# Shape of cleaned data: (8523, 9) - Remaining NAs: 0
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.41 MB (-69.49%)
#       item_weight  item_visibility              item_type    item_mrp  \
# 0        9.300000         0.016047                  Dairy  249.809204
# 1        5.920000         0.019278            Soft Drinks   48.269199
# 2       17.500000         0.016760                   Meat  141.617996
# 3       19.200001         0.000000  Fruits and Vegetables  182.095001
# 4        8.930000         0.000000              Household   53.861401
# ...           ...              ...                    ...         ...
# 8518     6.865000         0.056783            Snack Foods  214.521805
# 8519     8.380000         0.046982           Baking Goods  108.156998
# ...

# %%
klib.clean_column_names(df_train) # cleans and standardizes column names, also called inside data_cleaning()
# Out:
#       item_weight  item_visibility              item_type  item_mrp  \
# 0           9.300         0.016047                  Dairy  249.8092
# 1           5.920         0.019278            Soft Drinks   48.2692
# 2          17.500         0.016760                   Meat  141.6180
# 3          19.200         0.000000  Fruits and Vegetables  182.0950
# 4           8.930         0.000000              Household   53.8614
# ...           ...              ...                    ...       ...
# 8518        6.865         0.056783            Snack Foods  214.5218
# 8519        8.380         0.046982           Baking Goods  108.1570
# 8520       10.600         0.035186     Health and Hygiene   85.1224
# 8521        7.210         0.145221            Snack Foods  103.1332
# 8522       14.800         0.044878            Soft Drinks   75.4670
#
#       outlet_establishment_year outlet_size outlet_location_type  \
# 0                          1999      Medium               Tier 1
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_weight                8523 non-null   float64
#  1   item_visibility            8523 non-null   float64
#  2   item_type                  8523 non-null   object
#  3   item_mrp                   8523 non-null   float64
#  4   outlet_establishment_year  8523 non-null   int64
#  5   outlet_size                8523 non-null   object
#  6   outlet_location_type       8523 non-null   object
#  7   outlet_type                8523 non-null   object
#  8   item_outlet_sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 599.4+ KB

# %%
df_train=klib.convert_datatypes(df_train) # converts existing to more efficient dtypes, also called inside data_cleaning()
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_weight                8523 non-null   float32
#  1   item_visibility            8523 non-null   float32
#  2   item_type                  8523 non-null   category
#  3   item_mrp                   8523 non-null   float32
#  4   outlet_establishment_year  8523 non-null   int16
#  5   outlet_size                8523 non-null   category
#  6   outlet_location_type       8523 non-null   category
#  7   outlet_type                8523 non-null   category
#  8   item_outlet_sales          8523 non-null   float32
# dtypes: category(4), float32(4), int16(1)
# memory usage: 184.4 KB

# %%
klib.mv_col_handling(df_train)
# Out:
#       item_weight  item_visibility              item_type    item_mrp  \
# 0        9.300000         0.016047                  Dairy  249.809204
# 1        5.920000         0.019278            Soft Drinks   48.269199
# 2       17.500000         0.016760                   Meat  141.617996
# 3       19.200001         0.000000  Fruits and Vegetables  182.095001
# 4        8.930000         0.000000              Household   53.861401
# ...           ...              ...                    ...         ...
# 8518     6.865000         0.056783            Snack Foods  214.521805
# 8519     8.380000         0.046982           Baking Goods  108.156998
# 8520    10.600000         0.035186     Health and Hygiene   85.122398
# 8521     7.210000         0.145221            Snack Foods  103.133202
# 8522    14.800000         0.044878            Soft Drinks   75.467003
#
#       outlet_establishment_year outlet_size outlet_location_type  \
# ...

# %% [markdown]
# # Preprocessing Task before Model Building

# %% [markdown]
# ## 1) Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df_train['item_type']= le.fit_transform(df_train['item_type'])
df_train['outlet_size']= le.fit_transform(df_train['outlet_size'])
df_train['outlet_location_type']= le.fit_transform(df_train['outlet_location_type'])
df_train['outlet_type']= le.fit_transform(df_train['outlet_type'])

# %%
df_train
# Out:
#       item_weight  item_visibility  item_type    item_mrp  \
# 0        9.300000         0.016047          4  249.809204
# 1        5.920000         0.019278         14   48.269199
# 2       17.500000         0.016760         10  141.617996
# 3       19.200001         0.000000          6  182.095001
# 4        8.930000         0.000000          9   53.861401
# ...           ...              ...        ...         ...
# 8518     6.865000         0.056783         13  214.521805
# 8519     8.380000         0.046982          0  108.156998
# 8520    10.600000         0.035186          8   85.122398
# 8521     7.210000         0.145221         13  103.133202
# 8522    14.800000         0.044878         14   75.467003
#
#       outlet_establishment_year  outlet_size  outlet_location_type  \
# 0                          1999            1                     0
# 1                          2009            1                     2
# ...

# %% [markdown]
# # 2) Splitting our data into train and test

# %%
X=df_train.drop('item_outlet_sales',axis=1)

# %%
Y=df_train['item_outlet_sales']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, random_state=101, test_size=0.2)

# %% [markdown]
# # 3) Standarization

# %%
X.describe()
# Out:
#        item_weight  item_visibility    item_type     item_mrp  \
# count  8523.000000      8523.000000  8523.000000  8523.000000
# mean     12.857646         0.066132     7.226681   140.992767
# std       4.226124         0.051598     4.209990    62.275066
# min       4.555000         0.000000     0.000000    31.290001
# 25%       9.310000         0.026989     4.000000    93.826500
# 50%      12.857645         0.053931     6.000000   143.012802
# 75%      16.000000         0.094585    10.000000   185.643700
# max      21.350000         0.328391    15.000000   266.888397
#
#        outlet_establishment_year  outlet_size  outlet_location_type  \
# count                8523.000000  8523.000000           8523.000000
# mean                 1997.831867     1.170832              1.112871
# std                     8.371760     0.600327              0.812757
# min                  1985.000000     0.000000              0.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()

# %%
X_train_std= sc.fit_transform(X_train)

# %%
X_test_std= sc.transform(X_test)

# %%
X_train_std
# Out:
# array([[ 1.52290023,  0.68469731, -0.75847359, ..., -1.95699503,
#          1.08786619, -0.25964107],
#        [-1.239856  , -0.09514746,  1.60759199, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        [ 1.54667619, -0.0083859 ,  0.66116576, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        ...,
#        [-0.08197109, -0.91916229,  0.18795264, ...,  1.37953713,
#         -1.36527477, -0.25964107],
#        [-0.74888436,  1.21363045, -1.70489982, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        [ 0.67885675,  1.83915361,  0.4245592 , ..., -0.28872895,
#          1.08786619,  0.98524841]])

# %%
X_test_std
# Out:
# array([[-0.43860916, -0.21609253,  0.18795264, ..., -0.28872895,
#          1.08786619,  0.98524841],
#        [ 1.22570184, -0.52943464,  1.37098543, ..., -1.95699503,
#          1.08786619, -0.25964107],
#        [-1.2184578 ,  0.16277341, -1.46829326, ...,  1.37953713,
#         -1.36527477, -0.25964107],
#        ...,
#        [ 0.65508101,  0.8782423 ,  0.89777232, ..., -0.28872895,
#          1.08786619, -1.50453056],
#        [ 1.01171909, -1.28409256,  0.4245592 , ..., -0.28872895,
#          1.08786619,  0.98524841],
#        [-1.56558541, -1.09265374,  0.66116576, ..., -0.28872895,
#         -0.13870429, -0.25964107]])

# %%
Y_train
# Out:
# 3684     163.786804
# 1935    1607.241211
# 5142    1510.034424
# 4978    1784.343994
# 2299    3558.035156
#            ...
# 599     5502.836914
# 5695    1436.796387
# 8006    2167.844727
# 1361    2700.484863
# 1547     829.586792
# Name: item_outlet_sales, Length: 6818, dtype: float32

# %%
Y_test
# Out:
# 8179     904.822205
# 8355    2795.694092
# 3411    1947.464966
# 7089     872.863770
# 6954    2450.144043
#            ...
# 1317    1721.093018
# 4996     914.809204
# 531      370.184814
# 3891    1358.232056
# 6629    2418.185547
# Name: item_outlet_sales, Length: 1705, dtype: float32

# %%
import joblib

# %%
joblib.dump(sc,'sc1.sav')
# Out:
# ['sc1.sav']

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()

# %%
lr.fit(X_train_std,Y_train)
# Out:
# LinearRegression()

# %%
X_test.head()
# Out:
#       item_weight  item_visibility  item_type    item_mrp  \
# 8179    11.000000         0.055163          8  100.335800
# 8355    18.000000         0.038979         13  148.641800
# 3411     7.720000         0.074731          1   77.598602
# 7089    20.700001         0.049035          6   39.950600
# 6954     7.550000         0.027225          3  152.934006
#
#       outlet_establishment_year  outlet_size  outlet_location_type  \
# 8179                       2009            1                     2
# 8355                       1987            0                     2
# 3411                       1997            2                     0
# 7089                       2007            1                     1
# 6954                       2002            1                     1
#
#       outlet_type
# 8179            2
# 8355            1
# 3411            1
# 7089            1
# 6954            1

# %%
Y_pred_lr=lr.predict(X_test_std)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
print(r2_score(Y_test,Y_pred_lr))
print(mean_absolute_error(Y_test,Y_pred_lr))
print(np.sqrt(mean_squared_error(Y_test,Y_pred_lr)))
# Out:
# 0.5042161232533994
# 881.192313179906
# 1162.407799456348

# %% [markdown]
# #save your model

# %%
joblib.dump(lr,'lr1.sav')
# Out:
# ['lr1.sav']

# %%
from sklearn.ensemble import RandomForestRegressor
rf= RandomForestRegressor(n_estimators=1000)

# %%
rf.fit(X_train_std,Y_train)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
Y_pred_rf= rf.predict(X_test_std)

# %%
print(r2_score(Y_test,Y_pred_rf))
print(mean_absolute_error(Y_test,Y_pred_rf))
print(np.sqrt(mean_squared_error(Y_test,Y_pred_rf)))
# Out:
# 0.548568447822487
# 782.5841447623201
# 1109.1959389967517

# %%
pip install xgboost
# Out:
# ...
#      ---------------------------------------- 70.9/70.9 MB 1.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBRegressor as xgb
xb= xgb(objective='reg:squarederror', n_estimators=1000, learning_rate=0.1)

# %%
xb.fit(X_train_std,Y_train)
Y_pred_xb= rf.predict(X_test_std)

# %%
print(r2_score(Y_test,Y_pred_xb))
print(mean_absolute_error(Y_test,Y_pred_xb))
print(np.sqrt(mean_squared_error(Y_test,Y_pred_xb)))
# Out:
# 0.548568447822487
# 782.5841447623201
# 1109.1959389967517

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller

# %%
from statsmodels.tsa.vector_ar.var_model import VAR
model = VAR(df_train)
model_fit = model.fit()
predictions = model_fit.forecast(model_fit.y, steps=len(df_test))
predictions_df = pd.DataFrame(data=predictions, columns=df_test.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [90], in <cell line: 4>()
#       2 model = VAR(df_train)
#       3 model_fit = model.fit()
# ----> 4 predictions = model_fit.forecast(model_fit.y, steps=len(df_test))
#       5 predictions_df = pd.DataFrame(data=predictions, columns=df_test.columns)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\wrapper.py:34, in ResultsWrapper.__getattribute__(self, attr)
#      31 except AttributeError:
#      32     pass
# ---> 34 obj = getattr(results, attr)
#      35 data = results.model.data
#      36 how = self._wrap_attrs.get(attr)
#
# AttributeError: 'VARResults' object has no attribute 'y'

# %%
df_test.shape
df_test.head()
# Out:
#    Item_Weight  Item_Visibility    Item_Type  Item_MRP  \
# 0    20.750000         0.007565  Snack Foods  107.8622
# 1     8.300000         0.038428        Dairy   87.3198
# 2    14.600000         0.099575       Others  241.7538
# 3     7.315000         0.015388  Snack Foods  155.0340
# 4    12.695633         0.118599        Dairy  234.2300
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2007      Medium               Tier 2
# 2                       1998      Medium               Tier 3
# 3                       2007      Medium               Tier 2
# 4                       1985      Medium               Tier 3
#
#          Outlet_Type
# 0  Supermarket Type1
# 1  Supermarket Type1
# 2      Grocery Store
# 3  Supermarket Type1
# 4  Supermarket Type3

# %%
df_train.head()
# Out:
#    item_weight  item_visibility  item_type    item_mrp  \
# 0     9.300000         0.016047          4  249.809204
# 1     5.920000         0.019278         14   48.269199
# 2    17.500000         0.016760         10  141.617996
# 3    19.200001         0.000000          6  182.095001
# 4     8.930000         0.000000          9   53.861401
#
#    outlet_establishment_year  outlet_size  outlet_location_type  outlet_type  \
# 0                       1999            1                     0            1
# 1                       2009            1                     2            2
# 2                       1999            1                     0            1
# 3                       1998            1                     2            0
# 4                       1987            0                     2            1
#
#    item_outlet_sales
# 0        3735.137939
# 1         443.422791
# 2        2097.270020
# 3         732.380005
# 4         994.705200

# %%
df_train.shape
# Out:
# (8523, 9)

# %%
df_test.shape
# Out:
# (5681, 8)
