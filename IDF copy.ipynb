# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("Sales.csv")

# %%
df.head()
# Out:
#                     Product  Quantity Ordered  Price Each      Date
# 0    AAA Batteries (4-pack)                 1        2.99  01/01/19
# 1                    iPhone                 1      700.00  01/01/19
# 2  Lightning Charging Cable                 1       14.95  01/01/19
# 3  Lightning Charging Cable                 1       14.95  01/01/19
# 4    AAA Batteries (4-pack)                 1        2.99  01/01/19

# %%
df.describe()
# Out:
#        Quantity Ordered     Price Each
# count     342753.000000  342753.000000
# mean           1.126006     186.274045
# std            0.445804     335.223902
# min            1.000000       2.990000
# 25%            1.000000      11.950000
# 50%            1.000000      14.950000
# 75%            1.000000     150.000000
# max            9.000000    1700.000000

# %%
df = df.dropna()

# %%
df.describe()
# Out:
#        Quantity Ordered     Price Each
# count     342753.000000  342753.000000
# mean           1.126006     186.274045
# std            0.445804     335.223902
# min            1.000000       2.990000
# 25%            1.000000      11.950000
# 50%            1.000000      14.950000
# 75%            1.000000     150.000000
# max            9.000000    1700.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342753 entries, 0 to 342752
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Product           342753 non-null  object
#  1   Quantity Ordered  342753 non-null  int64
#  2   Price Each        342753 non-null  float64
#  3   Date              342753 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 10.5+ MB

# %%
# df.drop(index=df_with_id.head(200000).index, inplace=True)

# %%
df.head()
# Out:
#                     Product  Quantity Ordered  Price Each      Date
# 0    AAA Batteries (4-pack)                 1        2.99  01/01/19
# 1                    iPhone                 1      700.00  01/01/19
# 2  Lightning Charging Cable                 1       14.95  01/01/19
# 3  Lightning Charging Cable                 1       14.95  01/01/19
# 4    AAA Batteries (4-pack)                 1        2.99  01/01/19

# %%
parts = df["Date"].str.split("/", n = 3, expand = True)
df["month"]= parts[0].astype('int')
df["day"]= parts[1].astype('int')
df["year"]= ("20"+parts[2]).astype('int')

# %%
df.head()
# Out:
#                     Product  Quantity Ordered  Price Each      Date  month  \
# 0    AAA Batteries (4-pack)                 1        2.99  01/01/19      1
# 1                    iPhone                 1      700.00  01/01/19      1
# 2  Lightning Charging Cable                 1       14.95  01/01/19      1
# 3  Lightning Charging Cable                 1       14.95  01/01/19      1
# 4    AAA Batteries (4-pack)                 1        2.99  01/01/19      1
#
#    day  year
# 0    1  2019
# 1    1  2019
# 2    1  2019
# 3    1  2019
# 4    1  2019

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
le = LabelEncoder()
df_with_id = df
df_with_id['Product'] = le.fit_transform(df_with_id['Product'])
df_with_id.head()
# Out:
#    Product  Quantity Ordered  Price Each      Date  month  day  year
# 0        5                 1        2.99  01/01/19      1    1  2019
# 1       18                 1      700.00  01/01/19      1    1  2019
# 2       12                 1       14.95  01/01/19      1    1  2019
# 3       12                 1       14.95  01/01/19      1    1  2019
# 4        5                 1        2.99  01/01/19      1    1  2019

# %%
# df_with_id.drop(index=df_with_id.head(10000).index, inplace=True)

# %%
corr = df_with_id.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# C:\Users\bhowm\AppData\Local\Temp\ipykernel_21956\2838967803.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df_with_id.corr()
# <AxesSubplot: >

# %%
product_1_data = df_with_id[df_with_id['Product'] == 4]

# %%
product_1_data.head()
# Out:
#     Product  Quantity Ordered  Price Each      Date  month  day  year
# 5         4                 1        3.84  01/01/19      1    1  2019
# 8         4                 1        3.84  01/01/19      1    1  2019
# 22        4                 2        3.84  01/01/19      1    1  2019
# 23        4                 1        3.84  01/01/19      1    1  2019
# 27        4                 1        3.84  01/01/19      1    1  2019

# %%
product_1_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22528 entries, 5 to 199987
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product           22528 non-null  int32
#  1   Quantity Ordered  22528 non-null  int64
#  2   Price Each        22528 non-null  float64
#  3   Date              22528 non-null  object
#  4   month             22528 non-null  int32
#  5   day               22528 non-null  int32
#  6   year              22528 non-null  int32
# dtypes: float64(1), int32(4), int64(1), object(1)
# memory usage: 1.0+ MB

# %%
corr = product_1_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap for Product A')
plt.show()
# Out:
# C:\Users\bhowm\AppData\Local\Temp\ipykernel_21956\458313495.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = product_1_data.corr()

# %%
product_groups = df_with_id.groupby('Product')

for product, group in product_groups:
    corr = group.corr()
    
    plt.figure(figsize=(10, 8))
    
    sns.heatmap(corr, annot=True, cmap='coolwarm')
    
    plt.title('Correlation Heatmap for Product {}'.format(product))
    
    plt.show()
# Out:
# C:\Users\bhowm\AppData\Local\Temp\ipykernel_21956\2177435554.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = group.corr()

# %%
product_10_data = df_with_id[df_with_id['Product'] == 4]
product_10_data.head()
# Out:
#     Product  Quantity Ordered  Price Each      Date  month  day  year
# 5         4                 1        3.84  01/01/19      1    1  2019
# 8         4                 1        3.84  01/01/19      1    1  2019
# 22        4                 2        3.84  01/01/19      1    1  2019
# 23        4                 1        3.84  01/01/19      1    1  2019
# 27        4                 1        3.84  01/01/19      1    1  2019

# %%
corr = product_10_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap for Product 10')
plt.show()
# Out:
# C:\Users\bhowm\AppData\Local\Temp\ipykernel_21956\2878620344.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = product_10_data.corr()

# %%
product_1_data.head()
# Out:
#     Product  Quantity Ordered  Price Each      Date  month  day  year
# 5         4                 1        3.84  01/01/19      1    1  2019
# 8         4                 1        3.84  01/01/19      1    1  2019
# 22        4                 2        3.84  01/01/19      1    1  2019
# 23        4                 1        3.84  01/01/19      1    1  2019
# 27        4                 1        3.84  01/01/19      1    1  2019

# %%
product_1_data.tail()
# Out:
#         Product  Quantity Ordered  Price Each      Date  month  day  year
# 199948        4                 1        3.84  08/06/20      8    6  2020
# 199959        4                 1        3.84  08/06/20      8    6  2020
# 199964        4                 1        3.84  08/06/20      8    6  2020
# 199965        4                 1        3.84  08/06/20      8    6  2020
# 199987        4                 1        3.84  08/06/20      8    6  2020

# %%
product_1_data = product_1_data.groupby('Date').sum('Quantity Ordered')
product_1_data.index = pd.to_datetime(product_1_data.index)
product_1_data = product_1_data.drop(['Product','Price Each', 'month', 'day', 'year'], axis=1)
product_1_data.head()
# Out:
#             Quantity Ordered
# Date
# 2019-01-01                51
# 2020-01-01                74
# 2021-01-01                76
# 2019-01-02                42
# 2020-01-02                69

# %%
product_1_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 528 entries, 2019-01-01 to 2020-08-06
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Quantity Ordered  528 non-null    int64
# dtypes: int64(1)
# memory usage: 8.2 KB

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

col_name = 'Quantity Ordered'
product_1_data[['Quantity Ordered Scaled']] = scaler.fit_transform(product_1_data[['Quantity Ordered']])

# %%
product_1_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 528 entries, 2019-01-01 to 2020-08-06
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Quantity Ordered         528 non-null    int64
#  1   Quantity Ordered Scaled  528 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 12.4 KB

# %%
product_1_data.plot(
        # style='.',
        figsize=(15, 5),
        title='Sales over the period')
plt.show()

# %%
train = product_1_data.loc[product_1_data.index < '2020-12-10']
test = product_1_data.loc[product_1_data.index >= '2020-12-10']

fig, ax = plt.subplots(figsize=(15, 5))
train.plot(ax=ax, label='Training Set', title='Train/Test Split data')
test.plot(ax=ax, label='Test Set')
ax.axvline('2020-12-10', color='Gray', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %%
product_1_data.loc[(product_1_data.index > '2020-01-01') & (product_1_data.index < '2020-01-30')] \
    .plot(figsize=(15, 5), title='Month sales')
plt.show()

# %%
def create_features(product_1_data):
    """
    Creating time series features based on dataframe index.
    """
    product_1_data = product_1_data.copy()
    # df['hour'] = df.index.hour
    product_1_data['dayofweek'] = product_1_data.index.dayofweek
    product_1_data['quarter'] = product_1_data.index.quarter
    product_1_data['month'] = product_1_data.index.month
    product_1_data['year'] = product_1_data.index.year
    product_1_data['dayofyear'] = product_1_data.index.dayofyear
    product_1_data['dayofmonth'] = product_1_data.index.day
    product_1_data['weekofyear'] = product_1_data.index.isocalendar().week
    return product_1_data

product_1_data = create_features(product_1_data)

# %%
week_day_map = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday',
}
df_temp = product_1_data.copy()
df_temp['dayofweek'] = df_temp['dayofweek'].map(lambda index: week_day_map[index])

fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df_temp, x='dayofweek', y='Quantity Ordered')
ax.set_title('Sales on Week')
plt.show()

# %%
quantile_98 = df_temp['Quantity Ordered'].quantile(0.96)
producr_1_data_outliers = df_temp[df_temp['Quantity Ordered'] < quantile_98]

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=producr_1_data_outliers, x='dayofweek', y='Quantity Ordered')
ax.set_title('Sales on Week')
plt.show()

# %%
month_map = {
    1: 'Jan',
    2: 'Feb',
    3: 'Mar',
    4: 'Apr',
    5: 'May',
    6: 'Jun',
    7: 'Jul',
    8: 'Aug',
    9: 'Sep',
    10: 'Oct',
    11: 'Nov',
    12: 'Dec',
}
df_temp = product_1_data.copy()
df_temp['month'] = df_temp['month'].map(lambda index: month_map[index])

fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df_temp, x='month', y='Quantity Ordered', palette='Blues')
ax.set_title('Sales on Month')
plt.show()

# %%
month_map = {
    1: 'Jan',
    2: 'Feb',
    3: 'Mar',
    4: 'Apr',
    5: 'May',
    6: 'Jun',
    7: 'Jul',
    8: 'Aug',
    9: 'Sep',
    10: 'Oct',
    11: 'Nov',
    12: 'Dec',
}
df_temp_2 = producr_1_data_outliers.copy()
df_temp_2['month'] = df_temp_2['month'].map(lambda index: month_map[index])

fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df_temp_2, x='month', y='Quantity Ordered', palette='Blues')
ax.set_title('Sales on Month')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df_temp, x='quarter', y='Quantity Ordered', palette='Greens')
ax.set_title('Sales on Quarter')
plt.show()

# %%
product_1_data = producr_1_data_outliers

# %%
product_1_data
# Out:
#             Quantity Ordered  Quantity Ordered Scaled  dayofweek  quarter  \
# Date
# 2019-01-01                51                 0.448598    Tuesday        1
# 2020-01-01                74                 0.663551  Wednesday        1
# 2021-01-01                76                 0.682243     Friday        1
# 2019-01-02                42                 0.364486  Wednesday        1
# 2020-01-02                69                 0.616822   Thursday        1
# ...                      ...                      ...        ...      ...
# 2020-08-04                43                 0.373832    Tuesday        3
# 2019-08-05                69                 0.616822     Monday        3
# 2020-08-05                48                 0.420561  Wednesday        3
# 2019-08-06                63                 0.560748    Tuesday        3
# 2020-08-06                26                 0.214953   Thursday        3
#
#             month  year  dayofyear  dayofmonth  weekofyear
# Date
# 2019-01-01      1  2019          1           1           1
# 2020-01-01      1  2020          1           1           1
# 2021-01-01      1  2021          1           1          53
# 2019-01-02      1  2019          2           2           1
# 2020-01-02      1  2020          2           2           1
# ...           ...   ...        ...         ...         ...
# 2020-08-04      8  2020        217           4          32
# 2019-08-05      8  2019        217           5          32
# 2020-08-05      8  2020        218           5          32
# 2019-08-06      8  2019        218           6          32
# 2020-08-06      8  2020        219           6          32
#
# [506 rows x 9 columns]

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()

# col_name = 'Quantity Ordered'
# product_1_data[['Quantity Ordered Scaled']] = scaler.fit_transform(product_1_data[['Quantity Ordered']])

# %%
train = create_features(train)
test = create_features(test)

# FEATURES = ['dayofyear', 'dayofweek', 'quarter', 'month', 'year', 'dayofmonth']
FEATURES = ['dayofweek', 'quarter', 'month', 'year', 'dayofmonth']
TARGET = 'Quantity Ordered Scaled'

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from sklearn.linear_model import Lasso, Ridge

# %%
linreg_model = LinearRegression()
linreg_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
product_1_data_lr = product_1_data

# %%
test['prediction_lr'] = linreg_model.predict(X_test)
product_1_data_lr = product_1_data_lr.merge(test[['prediction_lr']], how='left', left_index=True, right_index=True)
ax = product_1_data_lr[['Quantity Ordered Scaled']].plot(figsize=(15, 5))
product_1_data_lr['prediction_lr'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Data and Prediction')
plt.show()

# %%
linreg_rmse = np.sqrt(mean_squared_error(test['Quantity Ordered'], test['prediction_lr']))
linreg_mae = mean_absolute_error(test['Quantity Ordered'], test['prediction_lr'])
linreg_r2 = r2_score(test['Quantity Ordered'], test['prediction_lr'])
print('Linear Regression RMSE: ', linreg_rmse)
print('Linear Regression MAE: ', linreg_mae)
print('Linear Regression R2 Score: ', linreg_r2)
# Out:
# Linear Regression RMSE:  70.8926695508882
# Linear Regression MAE:  68.95218113463297
# Linear Regression R2 Score:  -17.486240640327974

# %%
rf_model = RandomForestRegressor(n_estimators=100, max_depth=20)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=20)

# %%
product_1_data_rf = product_1_data

# %%
test['prediction_rf'] = rf_model.predict(X_test)
product_1_data_rf = product_1_data_rf.merge(test[['prediction_rf']], how='left', left_index=True, right_index=True)
ax = product_1_data_rf[['Quantity Ordered Scaled']].plot(figsize=(15, 5))
product_1_data_rf['prediction_rf'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Data and Prediction')
plt.show()

# %%
rf_rmse = np.sqrt(mean_squared_error(test['Quantity Ordered'], test['prediction_rf']))
rf_mae = mean_absolute_error(test['Quantity Ordered'], test['prediction_rf'])
rf_r2 = r2_score(test['Quantity Ordered'], test['prediction_rf'])
print('Random Forest RMSE: ', rf_rmse)
print('Random Forest MAE: ', rf_mae)
print('Random Forest R2 Score: ', rf_r2)
# Out:
# Random Forest RMSE:  70.76945460979587
# Random Forest MAE:  68.81345075485262
# Random Forest R2 Score:  -17.422036495716938

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=1000,
                       early_stopping_rounds=50,
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [22:30:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:0.21315	validation_1-rmse:0.19534
# [50]	validation_0-rmse:0.17744	validation_1-rmse:0.19697
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              objective='reg:linear', predictor=None, ...)

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
             index=reg.get_booster().feature_names,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
product_1_data_xg = product_1_data

# %%
test['prediction_xg'] = reg.predict(X_test)
product_1_data_xg = product_1_data_xg.merge(test[['prediction_xg']], how='left', left_index=True, right_index=True)
ax = product_1_data_xg[['Quantity Ordered Scaled']].plot(figsize=(15, 5))
product_1_data_xg['prediction_xg'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Data and Prediction')
plt.show()

# %%
ax = product_1_data_xg.loc[(product_1_data_xg.index > '2019-01-01') & (product_1_data_xg.index < '2019-01-08')]['Quantity Ordered'] \
    .plot(figsize=(15, 5), title='Week Of Data')
product_1_data_xg.loc[(product_1_data_xg.index > '2019-01-01') & (product_1_data_xg.index < '2019-01-08')]['prediction_xg'] \
    .plot()
plt.legend(['Truth Data','Prediction'])
plt.show()

# %%
xg_rmse = np.sqrt(mean_squared_error(test['Quantity Ordered'], test['prediction_xg']))
xg_mae = mean_absolute_error(test['Quantity Ordered'], test['prediction_xg'])
xg_r2 = r2_score(test['Quantity Ordered'], test['prediction_xg'])
print('XGBoost RMSE: ', xg_rmse)
print('XGBoost MAE: ', xg_mae)
print('XGBoost R2 Score: ', xg_r2)
# Out:
# XGBoost RMSE:  70.76659709610934
# XGBoost MAE:  68.81893481723554
# XGBoost R2 Score:  -17.42054884376476

# %%
linreg_stats = [linreg_rmse, linreg_mae, linreg_r2]
rf_stats = [rf_rmse, rf_mae, rf_r2]
xgb_stats = [xg_rmse, xg_mae, xg_r2]

# %%
plt.figure(figsize=(15,7))
plt.plot(linreg_stats)
plt.plot(rf_stats)
plt.plot(xgb_stats)
plt.title("Model Comparison between Linear Regression, Random Forest and XGboost")
plt.xticks([0,1,2], labels=['RMSE','MAE','R2 Score'])
plt.legend(["Linear Regression", "Random Forest", "XG Boost"])
plt.show()

# %%
test['prediction'] = test['prediction_rf']
product_1_data_rf['prediction'] = product_1_data_rf['prediction_rf']

# %%
test['error'] = np.abs(test[TARGET] - test['prediction'])
test['Dates'] = test.index.date

# %%
to_predict = pd.DataFrame(pd.date_range(start="2019-01-01", end="2021-08-01"), columns=['date'])
to_predict.index = pd.to_datetime(to_predict.date)

to_predict_feature = create_features(to_predict)
to_predict_feature = to_predict_feature[FEATURES]

to_predict_feature['prediction'] = reg.predict(to_predict_feature)
ax = product_1_data_rf[['Quantity Ordered Scaled']].plot(figsize=(15, 5))
product_1_data_rf['prediction'].plot(ax=ax, style='.')
to_predict_feature['prediction'].plot(ax=ax)
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Data and Prediction')
plt.show()

# %%
to_predict = pd.DataFrame(pd.date_range(start="2020-01-01", end="2020-01-30"), columns=['date'])
to_predict.index = pd.to_datetime(to_predict.date)

to_predict_feature = create_features(to_predict)
to_predict_feature = to_predict_feature[FEATURES]

to_predict_feature['prediction'] = reg.predict(to_predict_feature)
ax = to_predict_feature['prediction'].plot(figsize=(15, 5), style='.')
to_predict_feature['prediction'].plot(ax=ax)
plt.legend(['Predictions'])
ax.set_title('One Month Prediction')
plt.show()

# %%
test['prediction'] = test['prediction_xg']
product_1_data_xg['prediction'] = product_1_data_xg['prediction_xg']

# %%
to_predict = pd.DataFrame(pd.date_range(start="2019-01-01", end="2021-08-01"), columns=['date'])
to_predict.index = pd.to_datetime(to_predict.date)

to_predict_feature = create_features(to_predict)
to_predict_feature = to_predict_feature[FEATURES]

to_predict_feature['prediction'] = reg.predict(to_predict_feature)
ax = product_1_data_xg[['Quantity Ordered Scaled']].plot(figsize=(15, 5))
product_1_data_xg['prediction'].plot(ax=ax, style='.')
to_predict_feature['prediction'].plot(ax=ax)
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Data and Prediction')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# create sample data
start_date = "2019-01-01"
end_date = "2020-08-01"
dates = pd.date_range(start=start_date, end=end_date, freq="D")
data = np.random.randint(low=1, high=100, size=len(dates))
df = pd.DataFrame({"date": dates, "Quantity Ordered Scaled": data})
df.set_index("date", inplace=True)

# fit ARIMA model and forecast
model = ARIMA(df["Quantity Ordered Scaled"], order=(1, 1, 0))
result = model.fit()
forecast = result.forecast(steps=len(df))

# plot results
fig, ax = plt.subplots(figsize=(15, 5))
df["Quantity Ordered Scaled"].plot(ax=ax)
forecast.plot(ax=ax)
ax.legend(["Truth Data", "Predictions"])
ax.set_title("Raw Data and Prediction")
plt.show()
# Out:
# C:\Users\bhowm\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\bhowm\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\bhowm\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# import pandas as pd
# import numpy as np
# import random

# # Set the number of rows for the dataset
# num_rows = 100000

# # Create an empty dataframe with the desired columns
# df = pd.DataFrame(columns=['Order_ID', 'Product', 'Quantity_Ordered', 'Price_Each', 'State', 'Zip_Code', 'Date'])

# # Generate random values for each column and append to the dataframe
# for i in range(num_rows):
#     Order_ID=random.randint(1,500)
#     Product= random.randint(0, 18)
#     Quantity_Ordered = random.randint(0, 12)
#     Price_Each= round(random.uniform(5, 100), 2)
#     State= random.choice(['CA', 'WA', 'MA', 'TX','NY'])
#     Zip_Code=random.randint(0, 12)
#     Date = pd.Timestamp(np.random.choice(pd.date_range(start='2017-01-01', end='2017-12-31')))
#     df.loc[i] = [Order_ID,Product,Quantity_Ordered,Price_Each,State,Zip_Code,Date]

# # Save the dataframe to a CSV file
# df.to_csv('2017_sales.csv', index=False)

# %%
# import pandas as pd
# import numpy as np
# import random

# # Set the number of rows for the dataset
# num_rows = 100000

# # Create an empty dataframe with the desired columns
# df = pd.DataFrame(columns=['Order_ID', 'Product', 'Quantity_Ordered', 'Price_Each', 'State', 'Zip_Code', 'Date'])

# # Generate random values for each column and append to the dataframe
# for i in range(num_rows):
#     Order_ID=random.randint(1,500)
#     Product= random.randint(0, 18)
#     Quantity_Ordered = random.randint(0, 12)
#     Price_Each= round(random.uniform(5, 100), 2)
#     State= random.choice(['CA', 'WA', 'MA', 'TX','NY'])
#     Zip_Code=random.randint(0, 12)
#     Date = pd.Timestamp(np.random.choice(pd.date_range(start='2018-01-01', end='2018-12-31')))
#     df.loc[i] = [Order_ID,Product,Quantity_Ordered,Price_Each,State,Zip_Code,Date]

# # Save the dataframe to a CSV file
# df.to_csv('2018_sales.csv', index=False)
